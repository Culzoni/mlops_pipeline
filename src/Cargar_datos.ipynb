# %%
import pandas as pd 

df = pd.read_csv(r"C:\Proyectos\data science\mlops_pipeline\Base_de_datos.csv")


print(f"Filas y columnas del archivo: {df.shape}\n")

df.head()
# Out:
# Filas y columnas del archivo: (5000, 15)
#   customer_id  signup_month  age  tenure_months  region channel   plan  \
# 0     C100000            10   71             49   South     web  Basic
# 1     C100001            22   53             44    West   store  Basic
# 2     C100002            10   56             51   South     web  Basic
# 3     C100003            22   69             48  Center     app  Basic
# 4     C100004            20   50              7   South     app  Basic
#
#    sessions_week  avg_session_min  notif_click_rate  support_tickets_3m  \
# 0              4            10.11             0.318                   0
# 1              3             6.55             0.329                   0
# 2              6            12.10             0.120                   0
# 3              5            11.01             0.237                   0
# 4              7            12.97             0.145                   0
#
#    discount_pct_3m  late_payments_6m  auto_renew  churn
# ...
